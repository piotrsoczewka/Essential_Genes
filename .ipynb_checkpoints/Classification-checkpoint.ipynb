# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stat

# %%
# defyining function which allows changing the bar width.
# solution by jsgounot (https://stackoverflow.com/users/5016055/jsgounot)
def set_bar_width(ax, new_width):
    for patch in ax.patches:
        current_width = patch.get_width()
        patch.set_width(new_width)
        diff = current_width - new_width
        patch.set_x(patch.get_x() + diff * .5)

# %%
# importing data
all_genes_df = pd.read_csv('all_genes_df.csv')
all_genes_df.head()
# Out:
#    gene_ID  chromosome  gene_length[bp]  A_content[%]  T_content[%]  \
# 0  YAL001C           1             3573      35.32046      27.59586
# 1  YAL002W           1             3825      31.89542      30.92810
# 2  YAL003W           1              987      29.68592      31.10436
# 3  YAL005C           1             1929      29.13427      26.80145
# 4  YAL007C           1              648      30.86420      32.09877
#
#    C_content[%]  G_content[%]  GC_content[%]                          category
# 0      15.81304      21.27064       37.08368  GC content below \n length above
# 1      18.74510      18.43137       37.17647  GC content below \n length above
# 2      18.84498      20.36474       39.20972  GC content below \n length below
# 3      21.15086      22.91343       44.06429  GC content above \n length above
# 4      17.59259      19.44444       37.03703  GC content below \n length below

# %% [markdown]
# Data with essential and non essential genes are stored in txt files. I want to extract genes IDs and store them in respective lists.

# %%
# creating lists of essential and non essential genes form txt files

essential_genes = []
with open('essential_genes.txt') as file:
    for line in file:
        line_index_0 = line.split('\t')[0]
        if line_index_0[0] == 'Y':
            essential_genes.append(line_index_0)

            
nonessential_genes = []
with open('non_essential_genes.txt', encoding="utf8") as file:
    for line in file:
        line_index_0 = line.split('\t')[0]
        if line_index_0[0] == 'Y':
            nonessential_genes.append(line_index_0)

# %% [markdown]
# Let's take a quick look on the created lists and if there are any genes that are in both (which shouldn't happen)

# %%
len(essential_genes)
# Out:
# 1184

# %%
len(nonessential_genes)
# Out:
# 4870

# %%
ambiguous_genes = set(essential_genes) & set(nonessential_genes)
len(ambiguous_genes)
# Out:
# 111

# %% [markdown]
# Seems that there are 111 genes which are in both lists. Not too many but still, they should be removed from further analysis. I drop rowes from all_genes_df which have gene IDs that are in ambiguous_genes set.

# %%
rows_to_drop = all_genes_df[all_genes_df['gene_ID'].isin(ambiguous_genes)]
len(rows_to_drop)
# Out:
# 109

# %%
print(len(all_genes_df))
all_genes_df.drop(rows_to_drop.index, inplace=True)
print(len(all_genes_df))
# Out:
# 5894
# 5785

# %% [markdown]
# Dropping successfull. Turned out that among 111 genes in ambiguous_genes set, 2 were not in the all_genes_df. Now, let's label genes in all_genes_df as essential or non-essential.

# %%
essential = all_genes_df['gene_ID'].isin(essential_genes)
nonessential = all_genes_df['gene_ID'].isin(nonessential_genes)
condition_list = [essential, nonessential]
categories = ['yes', 'no']
all_genes_df['is_essential'] = np.select(condition_list, categories, default='unknown')

# %%
all_genes_df['is_essential'].value_counts()
# Out:
# no         4310
# yes        1007
# unknown     468
# Name: is_essential, dtype: int64

# %% [markdown]
# 468 genes are labeles as unknown. Should be removed.

# %%
unknow_rows_to_drop = all_genes_df[all_genes_df['is_essential'] == 'unknown']
print(len(unknow_rows_to_drop))

print(len(all_genes_df))
all_genes_df.drop(unknow_rows_to_drop.index, inplace=True)
print(len(all_genes_df))
# Out:
# 468
# 5785
# 5317

# %% [markdown]
# Before building clasification model, let's take a look if there are any obvious pattern in essential and non-essential genes distributions.

# %%
# defining medians for GC content and gene length
GC_median = all_genes_df['GC_content[%]'].median()
lenght_median = all_genes_df['gene_length[bp]'].median()


fig, ax = plt.subplots()
fig.set_size_inches([12,12])


ax = sns.scatterplot(data=all_genes_df, x="GC_content[%]", y='gene_length[bp]', s=5, hue='is_essential', palette=['#FF0000', '#00BCFF'])

ax.set_title('GC content vs. gene lenght', fontsize=15)
ax.set_xlabel('GC content [%]', fontsize=12)
ax.set_xticklabels(ax.get_xticks().astype(int), fontsize=11)
ax.set_ylabel('Gene length [bp]', fontsize=12)
ax.set_yticklabels(ax.get_yticks().astype(int), fontsize=11)


ax.axhline(lenght_median, c='b')
# ax.text(12, lenght_median + 200, 'Gene lenght \n median', c='b', fontsize=12)
ax.axvline(GC_median, c='r')
# ax.text(GC_median + 0.75, 14000, 'GC content \n median', c='r', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# No obvious pattern is visible. Let's also see charts with both groups separately. Instead of lines for medians of gene length and GC content, I use hue for 'category' column

# %%
sns.relplot(data=all_genes_df, x="GC_content[%]", y='gene_length[bp]',
                col='is_essential', s=5, hue='category')

plt.tight_layout()
plt.show()

# %% [markdown]
# Seems like there are more essential genes in category 'GC content below / length above'. I'm going to look at this more deeply. Firstly, I look at the proportions between the categories and how they look for essential and non-essential genes.

# %%
all_genes_df['category'].value_counts(normalize=True).sort_index()
# Out:
# GC content above \n length above    0.211209
# GC content above \n length below    0.280797
# GC content below \n length above    0.290013
# GC content below \n length below    0.217980
# Name: category, dtype: float64

# %%
all_genes_df[all_genes_df['is_essential'] == 'yes']['category'].value_counts(normalize=True).sort_index()
# Out:
# GC content above \n length above    0.194638
# GC content above \n length below    0.238332
# GC content below \n length above    0.361470
# GC content below \n length below    0.205561
# Name: category, dtype: float64

# %%
all_genes_df[all_genes_df['is_essential'] == 'no']['category'].value_counts(normalize=True).sort_index()
# Out:
# GC content above \n length above    0.215081
# GC content above \n length below    0.290719
# GC content below \n length above    0.273318
# GC content below \n length below    0.220882
# Name: category, dtype: float64

# %% [markdown]
# One can see that proportions for esential genes differer than for the whole dataset. Like visible on the chart, 'GC content below \n length above' category is enriched. To check if this disproportion is significant, I perform chi-squared test.

# %%
expected = all_genes_df['category'].value_counts().sort_index()
essential = all_genes_df[all_genes_df['is_essential'] == 'yes']['category'].value_counts().sort_index()
nonessential = all_genes_df[all_genes_df['is_essential'] == 'no']['category'].value_counts().sort_index()


chi2 = stat.chi2_contingency([essential, nonessential])
print(chi2)
print('p-value =', chi2[1])
# Out:
# (32.3442491178899, 4.428205122671789e-07, 3, array([[ 212.68779387,  282.76302426,  292.04325748,  219.50592439],
#        [ 910.31220613, 1210.23697574, 1249.95674252,  939.49407561]]))
# p-value = 4.428205122671789e-07

# %% [markdown]
# Very low p-value shows that there is a significant difference in distributions between essential and non-essential genes

# %%
expected
# Out:
# GC content above \n length above    1123
# GC content above \n length below    1493
# GC content below \n length above    1542
# GC content below \n length below    1159
# Name: category, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate, GridSearchCV, train_test_split, cross_val_predict
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix, make_scorer

# %%
# preparing y and X datasets
mapper = {'yes' : True, 'no' : False}
y = all_genes_df['is_essential'].map(mapper)
X = all_genes_df.drop(['is_essential', 'gene_ID', 'category', 'GC_content[%]'], axis=1)

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y)
# clf = KNeighborsClassifier(n_neighbors=5)
# clf.fit(X_train, y_train)
# y_pred = clf.predict(X_test)
# print(recall_score(y_test, y_pred, pos_label='yes'))
# print(confusion_matrix(y_test, y_pred, labels=['yes', 'no']))

# %%
def recall_neg_class(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    value = tn / (tn + fp)
    return value

# %%
# defying an estimator and list of degrees for checking


neighbors = list(range(1,10,2))

recall_mean_list = []
recall_std_list = []

recall_neg_means_list = []
recall_neg_std_list = []

euclidean_distance = []
manhattan_distance = []


for k in neighbors:

    clf = KNeighborsClassifier(n_neighbors = k)

    # selecting parameters for model tuning
    param = {'metric' : ['euclidean', 'manhattan']}
    best_param = []

    scoring = {'recall' : make_scorer(recall_score), \
               'recall_neg': make_scorer(recall_neg_class)}

    # creating best_degrees list for storing best degrees in each cross_validate split.

    # performing nested cross-validation. R2 score for model tuning and metrics in scoring for model evaluation

    cv_inner = 5
    cv_outer = 5

    best_model = GridSearchCV(clf, param, cv=cv_inner, scoring='recall')
    scores = cross_validate(best_model, X, y, cv=cv_outer, scoring=scoring, return_estimator=True)

    # calculating means and standard deviations of each metric scores from splits done by cross_validate()
    # appending lists with obtained values for tested k
    
    recall_mean = round((scores['test_recall']).mean(), 3)
    recall_mean_list.append(recall_mean)
    
    recall_std = round((scores['test_recall']).std(), 3)
    recall_std_list.append(recall_std)

    recall_neg_mean = round((scores['test_recall_neg']).mean(), 3)
    recall_neg_means_list.append(recall_neg_mean)
    
    recall_neg_std = round((scores['test_recall_neg']).std(), 3)
    recall_neg_std_list.append(recall_neg_std)

    # extracting best_params for each cross_validate() (outer loop) split
    for i in range(cv_outer):
        best_param.append(scores['estimator'][i].best_params_['metric'])
        
    euclidean_distance.append(best_param.count('euclidean'))
    manhattan_distance.append(best_param.count('manhattan'))

fig, ax = plt.subplots()
fig.set_size_inches([5, 5])

ax = plt.errorbar(neighbors, recall_mean_list, yerr=recall_std_list, capsize=5, marker='o', color='blue', linestyle='none')
ax = plt.errorbar(neighbors, recall_neg_means_list, yerr=recall_neg_std_list, capsize=5, marker='o', color='red', linestyle='none')
ax.set_xticks = [1,3,5,7,9]
ax.set_xticklabels = [1,3,5,7,9]
# ax.set_xlabel('K-neighhbor')
# ax.set_ylim(0,1)

# plt.tight_layout()
plt.show()

# %%
neighbors
# Out:
# [1, 3, 5, 7, 9, 11]

# %%
# defying an estimator and list of degrees for checking

clf = LogisticRegression()

# selecting parameters for model tuning
param = {'solver' : list(['newton-cg', 'lbfgs', 'liblinear'])}


# creating best_degrees list for storing best degrees in each cross_validate split.
best_solver = []

# preparing metrics for model evaluation
# scoring = recall_score

# performing nested cross-validation. R2 score for model tuning and metrics in scoring for model evaluation

cv_inner = 5
cv_outer = 5

best_model = GridSearchCV(clf, param, cv=cv_inner, scoring='recall')
scores = cross_validate(best_model, X, y, cv=cv_outer, scoring='recall', return_estimator=True)

# calculating means and standard deviations of each metric scores from splits done by cross_validate()
recall_mean = round((scores['test_score']).mean(), 3)
recall_std = round((scores['test_score']).std(), 3)


# extracting best_params for each cross_validate() (outer loop) split
for i in range(cv_outer):
    best_solver.append(scores['estimator'][i].best_params_['solver'])

print(scores['test_score'])
print('Mean recall =', recall_mean, "+/-", recall_std)
print(best_solver)
# Out:
# [0.         0.         0.00497512 0.00497512 0.        ]
# Mean recall = 0.002 +/- 0.002
# ['newton-cg', 'newton-cg', 'newton-cg', 'newton-cg', 'newton-cg']

# %%
# defying an estimator and list of degrees for checking

clf = RandomForestClassifier()

# selecting parameters for model tuning
param = {'n_estimators' : list(range(50,201,50))}

# creating best_degrees list for storing best degrees in each cross_validate split.
best_depth = []

# preparing metrics for model evaluation
# scoring = recall_score

# performing nested cross-validation. R2 score for model tuning and metrics in scoring for model evaluation

cv_inner = 5
cv_outer = 5

best_model = GridSearchCV(clf, param, cv=cv_inner, scoring='recall')
scores = cross_validate(best_model, X, y, cv=cv_outer, scoring='recall', return_estimator=True)

# calculating means and standard deviations of each metric scores from splits done by cross_validate()
recall_mean = round((scores['test_score']).mean(), 3)
recall_std = round((scores['test_score']).std(), 3)


# extracting best_params for each cross_validate() (outer loop) split
for i in range(cv_outer):
    best_depth.append(scores['estimator'][i].best_params_['n_estimators'])

print(scores['test_score'])
print('Mean recall =', recall_mean, "+/-", recall_std)
print(best_depth)
